# %% [markdown]
# # Goal perform analysis on dataset of different cars with their specifications

# %% [markdown]
# import dataset

# %%
import pandas as pd

# %%
A = pd.read_csv("D:/DATASCIENCE_PYTHON/Python/files/Cars93.csv")

# %% [markdown]
# Perform Data Profiling

# %%
A.head(3)
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0        25           31                None  ...          5    177
# 1        18           25  Driver & Passenger  ...          5    195
# 2        20           26         Driver only  ...          5    180
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# 0        102     68           37            26.5         11.0    2705
# 1        115     71           38            30.0         15.0    3560
# 2        102     67           37            28.0         14.0    3375
#
#     Origin           Make
# 0  non-USA  Acura Integra
# 1  non-USA   Acura Legend
# 2  non-USA        Audi 90
# ...

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             89 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %%
A.describe()
# Out:
#        Unnamed: 0  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count   93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean    47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std     26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min      1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%     24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%     47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%     70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max     93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %%
A.shape
# Out:
# (93, 28)

# %% [markdown]
# Missing value treatment

# %%
import matplotlib.pyplot as plt

# %%
A.isna().sum().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
Q = pd.DataFrame(A.isna().sum(),columns=['missing_values'])

# %%
Q[Q.missing_values>0]
# Out:
#                 missing_values
# AirBags                      4
# Rear.seat.room               2
# Luggage.room                11

# %% [markdown]
# Seperating categorical and continous columns from the dataset

# %%
cat = []
con = []
for i in A.columns:
    if (A[i].dtypes=='object'):
        cat.append(i)
    else:
        con.append(i)

# %%
cat # categorical columns
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin',
#  'Make']

# %%
con #continuous columns
# Out:
# ['Unnamed: 0',
#  'Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight']

# %%
#Treating missing values of continuous columns
X = A[['Rear.seat.room']].mean()
A["Rear.seat.room"]= A["Rear.seat.room"].fillna(X[0])

# %%
X = A[["Luggage.room"]].mean()
A["Luggage.room"] =  A["Luggage.room"].fillna(X[0])

# %%
# Treating missing values of categorical columns
X = A.AirBags.mode()
A.AirBags = A.AirBags.fillna(X[0])

# %%
A.isna().sum()
# Out:
# Unnamed: 0            0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               0
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        0
# Luggage.room          0
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %%
A = A.drop(labels=["Unnamed: 0"],axis=1)

# %%
A = A.drop(labels=["Make","Model","Manufacturer"],axis=1)

# %% [markdown]
# Exploratory Data Analysis Univariate Analysis

# %%
list(A.columns)
# Out:
# ['Type',
#  'Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Man.trans.avail',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight',
#  'Origin']

# %%
cat
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin',
#  'Make']

# %%
con
# Out:
# ['Unnamed: 0',
#  'Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight']

# %% [markdown]
# univariate analysis of continuous columns

# %%
import seaborn as sb
sb.distplot (A.Passengers)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Passengers', ylabel='Density'>

# %%
cat = []
con = []
for i in A.columns:
    if (A[i].dtypes=='object'):
        cat.append(i)
    else:
        con.append(i)

# %%
for i in con:
    sb.distplot(A[i])
    plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for i in con:
    A[i].hist()
    plt.xlabel(i)
    plt.show()

# %% [markdown]
# univariate analysis of categorical columns

# %%
cat
# Out:
# ['Type', 'AirBags', 'DriveTrain', 'Cylinders', 'Man.trans.avail', 'Origin']

# %%
for i in cat:
    sb.countplot(A[i])
    plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# The above countplot represents data values in different categorical columns of dataset.

# %%
for i in cat:
    A[i].value_counts().plot(kind="barh")
    plt.xlabel(i)
    plt.show()

# %% [markdown]
# The above barchart represents data values in different categorical columns

# %%
for i in cat:
    A[i].value_counts().plot(kind="pie")
    plt.xlabel(i)
    plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
for i in A.columns:
    if (A[i].dtypes=="object"):
        sb.boxplot(A[i],A.Width) # boxplot between categorical and continuous
        plt.xlabel(i)
        plt.ylabel('Width')
        plt.show()
    else:
        plt.scatter(A[i],A.Width) # scatterplot between continuous and continuous
        plt.xlabel(i)
        plt.ylabel('Width')
        plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in A.columns:
    if(A[i].dtypes == 'object'):
        sb.boxplot(A[i],A.Width)#Boxplot between categorical and continuous columns
        plt.xlabel(i)
        plt.ylabel('Width')
        plt.show()
    else:
        plt.scatter(A[i],A.Width)# Scatter plot between continuous and continuous columns
        plt.xlabel('Width')
        plt.ylabel(i)
        plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in A.columns:
   if(A[i].dtypes=="object"):
    sb.countplot(A.Origin,hue=A[i])#Countplot with hue between categorical and categorical columns
    plt.ylabel(i)
    plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
pd.crosstab(A.Origin,A.Type) #crosstab between categorical and categorical columns.
# Out:
# Type     Compact  Large  Midsize  Small  Sporty  Van
# Origin
# USA            7     11       10      7       8    5
# non-USA        9      0       12     14       6    4

# %%
pd.crosstab(A.AirBags,A.Origin)
# Out:
# Origin              USA  non-USA
# AirBags
# Driver & Passenger    8        6
# Driver only          24       22
# None                 16       17

# %%
pd.crosstab(A.Cylinders,A.Origin)
# Out:
# Origin     USA  non-USA
# Cylinders
# 3            0        3
# 4           22       27
# 5            0        2
# 6           20       11
# 8            6        1
# rotary       0        1

# %%
pd.crosstab(A.Origin,A['Man.trans.avail'])
# Out:
# Man.trans.avail  No  Yes
# Origin
# USA              26   22
# non-USA           6   39

# %% [markdown]
# Multivariate Analysis

# %%
sb.pairplot(A)

# %%
sb.heatmap(A.corr())
# Out:
# <AxesSubplot:>
